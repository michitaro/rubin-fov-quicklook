# %%
import pickle

# %%
from pathlib import Path

# %%
ppccd = pickle.loads(Path('./example/preprocessed_ccd.pkl').read_bytes())

# %%
from matplotlib import pyplot

# %%
import numpy

# %%
pyplot.imshow(numpy.arcsinh(ppccd.pool[100:-100, 100:-100]))

# %%
import astropy.io.fits as afits
